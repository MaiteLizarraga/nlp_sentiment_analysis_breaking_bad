# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install ffmpeg

import whisper

model = whisper.load_model("medium")  # or use "large" for better accuracy
result = model.transcribe("/content/drive/Shareddrives/Capstone/preprocessing_wip_Maite/wav/comprimido/BB1x01.wav", language="en")

print(result["text"])  # Output transcribed text
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-mmny8jr6
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-mmny8jr6
#   Resolved https://github.com/openai/whisper.git to commit 279133e3107392276dc509148da1f41bfb532c7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
